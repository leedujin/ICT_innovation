# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.8.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape =', x_train.shape, ', x_test.shape =', x_test.shape)
print('t_train.shape =', t_train.shape, ', t_test.shape =', t_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# x_train.shape = (60000, 28, 28) , x_test.shape = (10000, 28, 28)
# t_train.shape = (60000,) , t_test.shape = (10000,)

# %%
model = Sequential()

model.add(Conv2D(input_shape = (28, 28, 1),
                 kernel_size = 3, filters = 32,
                 strides = (1, 1), activation = 'relu', use_bias = True, padding = 'SAME'))
model.add(MaxPool2D(pool_size = (2, 2), padding = 'SAME'))

model.add(Conv2D(kernel_size = 3, filters = 32, strides = (1, 1), activation = 'relu', padding = 'SAME'))
model.add(MaxPool2D(pool_size = (2, 2), padding = 'SAME'))
model.add(Flatten())

model.add(Dense(10, activation = 'softmax'))

# %%
model.compile(optimizer = Adam(learning_rate = 0.001),
              loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 32)        9248
#
#  max_pooling2d_8 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  flatten_5 (Flatten)         (None, 1568)              0
#
#  dense_2 (Dense)             (None, 10)                15690
#
# =================================================================
# Total params: 25,258
# Trainable params: 25,258
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1, 28, 28, 1), t_train, batch_size = 50, epochs = 50, validation_split = 0.2)
# Out:
# Epoch 1/50
# 960/960 [==============================] - 15s 6ms/step - loss: 0.2789 - accuracy: 0.9215 - val_loss: 0.1241 - val_accuracy: 0.9662
# Epoch 2/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.1029 - accuracy: 0.9704 - val_loss: 0.0832 - val_accuracy: 0.9767
# Epoch 3/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0733 - accuracy: 0.9784 - val_loss: 0.0744 - val_accuracy: 0.9778
# Epoch 4/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0592 - accuracy: 0.9829 - val_loss: 0.0729 - val_accuracy: 0.9783
# Epoch 5/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0502 - accuracy: 0.9850 - val_loss: 0.0737 - val_accuracy: 0.9778
# Epoch 6/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0428 - accuracy: 0.9873 - val_loss: 0.0705 - val_accuracy: 0.9798
# Epoch 7/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0374 - accuracy: 0.9887 - val_loss: 0.0634 - val_accuracy: 0.9817
# Epoch 8/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0331 - accuracy: 0.9903 - val_loss: 0.0662 - val_accuracy: 0.9800
# Epoch 9/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0286 - accuracy: 0.9913 - val_loss: 0.0676 - val_accuracy: 0.9791
# Epoch 10/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0252 - accuracy: 0.9922 - val_loss: 0.0699 - val_accuracy: 0.9805
# Epoch 11/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0670 - val_accuracy: 0.9815
# Epoch 12/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0193 - accuracy: 0.9945 - val_loss: 0.0737 - val_accuracy: 0.9803
# Epoch 13/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.0720 - val_accuracy: 0.9801
# Epoch 14/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0148 - accuracy: 0.9956 - val_loss: 0.0817 - val_accuracy: 0.9802
# Epoch 15/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0126 - accuracy: 0.9968 - val_loss: 0.0769 - val_accuracy: 0.9808
# Epoch 16/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.0753 - val_accuracy: 0.9807
# Epoch 17/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0104 - accuracy: 0.9970 - val_loss: 0.0785 - val_accuracy: 0.9803
# Epoch 18/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.0782 - val_accuracy: 0.9808
# Epoch 19/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.0824 - val_accuracy: 0.9793
# Epoch 20/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0824 - val_accuracy: 0.9814
# Epoch 21/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.0872 - val_accuracy: 0.9806
# Epoch 22/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 0.0902 - val_accuracy: 0.9817
# Epoch 23/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0859 - val_accuracy: 0.9806
# Epoch 24/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.0923 - val_accuracy: 0.9806
# Epoch 25/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.0909 - val_accuracy: 0.9808
# Epoch 26/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0918 - val_accuracy: 0.9813
# Epoch 27/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.0995 - val_accuracy: 0.9801
# Epoch 28/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0965 - val_accuracy: 0.9807
# Epoch 29/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1079 - val_accuracy: 0.9806
# Epoch 30/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.1021 - val_accuracy: 0.9808
# Epoch 31/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.1220 - val_accuracy: 0.9772
# Epoch 32/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0954 - val_accuracy: 0.9822
# Epoch 33/50
# 960/960 [==============================] - 5s 5ms/step - loss: 9.5313e-04 - accuracy: 0.9999 - val_loss: 0.1032 - val_accuracy: 0.9816
# Epoch 34/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.1036 - val_accuracy: 0.9813
# Epoch 35/50
# 960/960 [==============================] - 5s 5ms/step - loss: 9.8317e-04 - accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 0.9797
# Epoch 36/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1269 - val_accuracy: 0.9778
# Epoch 37/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1077 - val_accuracy: 0.9804
# Epoch 38/50
# 960/960 [==============================] - 5s 5ms/step - loss: 4.9503e-04 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9810
# Epoch 39/50
# 960/960 [==============================] - 5s 5ms/step - loss: 5.0965e-04 - accuracy: 0.9999 - val_loss: 0.1177 - val_accuracy: 0.9801
# Epoch 40/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.1224 - val_accuracy: 0.9793
# Epoch 41/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.1217 - val_accuracy: 0.9802
# Epoch 42/50
# 960/960 [==============================] - 5s 5ms/step - loss: 5.1184e-04 - accuracy: 0.9999 - val_loss: 0.1142 - val_accuracy: 0.9812
# Epoch 43/50
# 960/960 [==============================] - 5s 5ms/step - loss: 1.8977e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9818
# Epoch 44/50
# 960/960 [==============================] - 5s 5ms/step - loss: 1.4387e-04 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9812
# Epoch 45/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.1353 - val_accuracy: 0.9790
# Epoch 46/50
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1215 - val_accuracy: 0.9808
# Epoch 47/50
# 960/960 [==============================] - 5s 5ms/step - loss: 2.4208e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9812
# Epoch 48/50
# 960/960 [==============================] - 5s 5ms/step - loss: 1.3573e-04 - accuracy: 1.0000 - val_loss: 0.1189 - val_accuracy: 0.9807
# Epoch 49/50
# 960/960 [==============================] - 5s 5ms/step - loss: 1.0768e-04 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9808
# Epoch 50/50
# 960/960 [==============================] - 5s 5ms/step - loss: 1.0215e-04 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9804

# %%
model.evaluate(x_test.reshape(-1, 28, 28, 1), t_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1208 - accuracy: 0.9821
# [0.12081433087587357, 0.9821000099182129]
