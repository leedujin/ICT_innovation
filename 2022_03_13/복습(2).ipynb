# %%
import glob
import os
import shutil
import cv2

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import load_model

# %%
import zipfile

with zipfile.ZipFile('/content/my_test_image.zip', 'r') as target_file:
  target_file.extractall('my_test_image')

# %%
try :
  cnn = load_model('/content/cifar10_accuracy_82v1.h5')
  cnn.summary()

except Exception as err:
  print(err)
# Out:
# Unable to open file (truncated file: eof = 6291456, sblock->base_addr = 0, stored_eof = 8868320)
